# %%
import re

# %%
text = "I K L N am Abhishek Timsian 90123sdsdAsddSDDD9"

# %%
match = re.findall(r"[A-Z0-9]", text)
match
# Out:
# ['I',
#  'K',
#  'L',
#  'N',
#  'A',
#  'T',
#  '9',
#  '0',
#  '1',
#  '2',
#  '3',
#  'A',
#  'S',
#  'D',
#  'D',
#  'D',
#  '9']
